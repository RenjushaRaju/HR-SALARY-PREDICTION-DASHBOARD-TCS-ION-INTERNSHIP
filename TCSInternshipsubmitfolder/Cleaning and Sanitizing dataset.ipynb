# %%
import sys#only needed to determine python version number
import os #required to set current working directory
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

#While displaying data ,ignore the warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('C:\\Users\\HP\\Desktop\\tcsioninternship\\HRDataset_v14.csv')

# %%
#Display the columns in dataset
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
df.tail()
# Out:
#           Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 306      Woodson, Jason  10135          0                0         1
# 307  Ybarra, Catherine   10301          0                0         0
# 308    Zamora, Jennifer  10010          0                0         0
# 309         Zhou, Julia  10043          0                0         0
# 310       Zima, Colleen  10271          0                4         0
#
#      EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 306            1       5            3                       0   65893  ...
# 307            5       5            1                       0   48513  ...
# 308            1       3            4                       0  220450  ...
# 309            1       3            3                       0   89292  ...
# 310            1       5            3                       0   45046  ...
#
#         ManagerName  ManagerID  RecruitmentSource PerformanceScore  \
# ...

# %%
df.columns
# Out:
# Index(['Employee_Name', 'EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID',
#        'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID',
#        'Salary', 'Termd', 'PositionID', 'Position', 'State', 'Zip', 'DOB',
#        'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc',
#        'DateofHire', 'DateofTermination', 'TermReason', 'EmploymentStatus',
#        'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource',
#        'PerformanceScore', 'EngagementSurvey', 'EmpSatisfaction',
#        'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30',
#        'Absences'],
#       dtype='object')

# %%
df.shape
# Out:
# (311, 36)

# %%
df.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
#Method to Calculate the Average of a Pandas DataFrame Column
df = pd.DataFrame(df)
print(df.mean())
# Out:
# EmpID                     10156.000000
# MarriedID                     0.398714
# MaritalStatusID               0.810289
# GenderID                      0.434084
# EmpStatusID                   2.392283
# DeptID                        4.610932
# PerfScoreID                   2.977492
# FromDiversityJobFairID        0.093248
# Salary                    69020.684887
# Termd                         0.334405
# PositionID                   16.845659
# Zip                        6555.482315
# ManagerID                    14.570957
# EngagementSurvey              4.110000
# EmpSatisfaction               3.890675
# SpecialProjectsCount          1.218650
# DaysLateLast30                0.414791
# Absences                     10.237942
# dtype: float64

# %%
#checking duplicates
df[df.duplicated()]
#checking duplicates,repeated and unknown and found that there is no duplicate values
# Out:
# Empty DataFrame
# Columns: [Employee_Name, EmpID, MarriedID, MaritalStatusID, GenderID, EmpStatusID, DeptID, PerfScoreID, FromDiversityJobFairID, Salary, Termd, PositionID, Position, State, Zip, DOB, Sex, MaritalDesc, CitizenDesc, HispanicLatino, RaceDesc, DateofHire, DateofTermination, TermReason, EmploymentStatus, Department, ManagerName, ManagerID, RecruitmentSource, PerformanceScore, EngagementSurvey, EmpSatisfaction, SpecialProjectsCount, LastPerformanceReview_Date, DaysLateLast30, Absences]
# Index: []
#
# [0 rows x 36 columns]

# %%
from datetime import date

#Make the format of date time correct
# Now convert these to datetime

df['DateofHire'] = pd.to_datetime(df['DateofHire'])
df['DateofTermination'] = pd.to_datetime(df['DateofTermination'])
df['LastPerformanceReview_Date'] = pd.to_datetime(df['LastPerformanceReview_Date'])
df['DOB'] = pd.to_datetime(df['DOB'])

# Verify and confirm
df[['DOB','DateofHire','DateofTermination','LastPerformanceReview_Date']].head(5)
# Out:
#          DOB DateofHire DateofTermination LastPerformanceReview_Date
# 0 1983-07-10 2011-07-05               NaT                 2019-01-17
# 1 1975-05-05 2015-03-30        2016-06-16                 2016-02-24
# 2 1988-09-19 2011-07-05        2012-09-24                 2012-05-15
# 3 1988-09-27 2008-01-07               NaT                 2019-01-03
# 4 1989-09-08 2011-07-11        2016-09-06                 2016-02-01

# %%
from datetime import date
def experienceCalc(doj, dot):
    today = date.today()
    return np.where(pd.isna(dot), today.year - doj.dt.year, dot.dt.year - doj.dt.year)
 
df['YearsOfExperience'] = experienceCalc(df['DateofHire'], df['DateofTermination'])
df[['YearsOfExperience']]
# Out:
#      YearsOfExperience
# 0                 11.0
# 1                  1.0
# 2                  1.0
# 3                 14.0
# 4                  5.0
# ..                 ...
# 306                8.0
# 307                7.0
# 308               12.0
# 309                7.0
# 310                8.0
#
# [311 rows x 1 columns]

# %%
df['Date'] = pd.to_datetime(df.DOB)

df['Date']
# Out:
# 0     1983-07-10
# 1     1975-05-05
# 2     1988-09-19
# 3     1988-09-27
# 4     1989-09-08
#          ...
# 306   1985-05-11
# 307   1982-05-04
# 308   1979-08-30
# 309   1979-02-24
# 310   1978-08-17
# Name: Date, Length: 311, dtype: datetime64[ns]

# %%
from datetime import date
def from_dob_to_age(born):
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
df['Age']=df['Date'].apply(lambda x: from_dob_to_age(x))

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#    PerformanceScore  EngagementSurvey EmpSatisfaction SpecialProjectsCount  \
# ...

# %%
#missing values
df.isna().sum()
# Out:
# Employee_Name                   0
# EmpID                           0
# MarriedID                       0
# MaritalStatusID                 0
# GenderID                        0
# EmpStatusID                     0
# DeptID                          0
# PerfScoreID                     0
# FromDiversityJobFairID          0
# Salary                          0
# Termd                           0
# PositionID                      0
# Position                        0
# State                           0
# Zip                             0
# DOB                             0
# Sex                             0
# MaritalDesc                     0
# CitizenDesc                     0
# HispanicLatino                  0
# RaceDesc                        0
# DateofHire                      0
# DateofTermination             207
# TermReason                      0
# EmploymentStatus                0
# Department                      0
# ManagerName                     0
# ...

# %%
#There are 207 null values in DateofTermination field.
df = df.fillna(df['DateofTermination'].value_counts().index[0])

# %%
df_imp=df.drop(['DateofTermination'],axis=1)

# %%
#Dividing columns into numerical and categorical
numcol=[]
catcol=[]
for col in df.columns:
    try:
        if df[col].dtype=='O':
            catcol.append(col)
        else:
            numcol.append(col)
    except:
        print("An error occurred")
print("List of categorical columns",catcol) 
print("List of numerical columns",numcol)
# Out:
# List of categorical columns ['Employee_Name', 'Position', 'State', 'Sex', 'MaritalDesc', 'CitizenDesc', 'HispanicLatino', 'RaceDesc', 'TermReason', 'EmploymentStatus', 'Department', 'ManagerName', 'ManagerID', 'RecruitmentSource', 'PerformanceScore']
# List of numerical columns ['EmpID', 'MarriedID', 'MaritalStatusID', 'GenderID', 'EmpStatusID', 'DeptID', 'PerfScoreID', 'FromDiversityJobFairID', 'Salary', 'Termd', 'PositionID', 'Zip', 'DOB', 'DateofHire', 'DateofTermination', 'EngagementSurvey', 'EmpSatisfaction', 'SpecialProjectsCount', 'LastPerformanceReview_Date', 'DaysLateLast30', 'Absences', 'YearsOfExperience', 'Date', 'Age']

# %%
#Data visualization using matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
for ncol in numcol:
    plt.hist(df[ncol])
    plt.xlabel(ncol)
    plt.plot()
    plt.show()

# %%
for ncol in numcol:
    sns.histplot(df[ncol],kde=True)
    plt.xlabel(ncol)
    plt.plot()
    plt.show()

# %%
#In salary,there is a tail towards end.Data is right skewed
#EmpSatisfaction is multimodal distribution.There are two or three top points.

for ncol in numcol:
    print(ncol)
    sns.boxplot(df[ncol])
    plt.xlabel(ncol)
    plt.plot()
    plt.show()
# Out:
# EmpID
# MarriedID
# MaritalStatusID
# GenderID
# EmpStatusID
# DeptID
# PerfScoreID
# FromDiversityJobFairID
# Salary
# Termd
# PositionID
# Zip
# DOB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-f320af2970b5> in <module>
#       4 for ncol in numcol:
#       5     print(ncol)
# ----> 6     sns.boxplot(df[ncol])
#       7     plt.xlabel(ncol)
#       8     plt.plot()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2238 ):
#    2239
# ...

# %%
for ncol in catcol:
    print(ncol)
    sns.countplot(df[ncol])
    plt.xlabel(ncol)
    plt.xticks(rotation=90)
    plt.plot()
    plt.show()
# Out:
# Employee_Name
# Position
# State
# Sex
# MaritalDesc
# CitizenDesc
# HispanicLatino
# RaceDesc
# TermReason
# EmploymentStatus
# Department
# ManagerName
# ManagerID
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\algorithms.py in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    2122         try:
# -> 2123             sorter = values.argsort()
#    2124             ordered = values.take(sorter)
#
# TypeError: '<' not supported between instances of 'Timestamp' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-4cfb1a797410> in <module>
#       1 for ncol in catcol:
#       2     print(ncol)
# ----> 3     sns.countplot(df[ncol])
#       4     plt.xlabel(ncol)
# ...

# %%
from sklearn.impute import SimpleImputer
imp_median=SimpleImputer(missing_values=np.nan,strategy='median')
df=pd.DataFrame(imp_median.fit_transform(df[numcol]),columns=numcol)

# %%
df.plot(kind='box',subplots=True,layout=(8,4),figsize=(18,24));

# %%
#outlier removal
import numpy as np

Q1=np.percentile(df['Salary'],25,interpolation='midpoint')
Q2=np.percentile(df['Salary'],50,interpolation='midpoint')
Q3=np.percentile(df['Salary'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
df['Salary'].median()
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR
print(low_lim)
print(Up_lim)
outlier=[]

# %%
for x in df['Salary']:
    if((x>Up_lim)or(x<low_lim)):
        outlier.append(x)
outlier        


ind1=df['Salary']>Up_lim
in2=df.loc[ind1].index
df.drop(in2,inplace=True)
ind2=df['Salary']<low_lim
in3=df.loc[ind2].index
df.drop(in3,inplace=True)



plt.boxplot(df['Salary'])
plt.title('Boxplot of Salary')

# %%
Q1=np.percentile(df['PositionID'],25,interpolation='midpoint')
Q2=np.percentile(df['PositionID'],50,interpolation='midpoint')
Q3=np.percentile(df['PositionID'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
df['PositionID'].median()
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR
print(low_lim)
print(Up_lim)
outlier=[]

# %%
Q1=np.percentile(df['PositionID'],25,interpolation='midpoint')
Q2=np.percentile(df['PositionID'],50,interpolation='midpoint')
Q3=np.percentile(df['PositionID'],75,interpolation='midpoint')
print(Q1)
print(Q2)
print(Q3)
df['PositionID'].median()
IQR=Q3-Q1
low_lim=Q1-1.5*IQR
Up_lim=Q3+1.5*IQR
print(low_lim)
print(Up_lim)
outlier=[]

# %%
for x in df['PositionID']:
    if((x>Up_lim)or(x<low_lim)):
        outlier.append(x)
outlier        


ind1=df['PositionID']>Up_lim
in2=df.loc[ind1].index
df.drop(in2,inplace=True)
ind2=df['PositionID']<low_lim
in3=df.loc[ind2].index
df.drop(in3,inplace=True)



plt.boxplot(df['PositionID'])
plt.title('Boxplot of PositionID')

# %% [markdown]
# ## Encoding

# %%
#LAbel encoding
from sklearn import model_selection, preprocessing
for c in df.columns:
    if df[c].dtype == 'object':
        lbl = preprocessing.LabelEncoder()
        lbl.fit(list(df[c].values)) 
        df[c] = lbl.transform(list(df[c].values))
        #x_train.drop(c,axis=1,inplace=True)

# %% [markdown]
# ## Scaling

# %%
from sklearn import preprocessing
stand=preprocessing.StandardScaler()
df=stand.fit_transform
